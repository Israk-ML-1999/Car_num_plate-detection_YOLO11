# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/gdrive/MyDrive/yolo11_num_plate detection/number_plat/data.yaml",  # path to dataset YAML
    epochs=5,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # use GPU device 0
)
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train10/weights/best.pt")

# Perform object detection on an image
results = model("/content/gdrive/MyDrive/yolo11_num_plate detection/number_plat/data/Cars289_png_jpg.rf.cb69e198ac53f62dd575fc7e8bd21559.jpg", save=True)
results[0].show()
